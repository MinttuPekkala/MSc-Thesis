# %% [markdown]
# Import Python libraries

# %%
import numpy as np
import xarray as xr
import cartopy.crs as ccrs
import pandas as pd
import matplotlib.pyplot as plt
import glob
import pyresample
import dask.dataframe as dd
import seaborn as sns
from tqdm import tqdm
from matplotlib.patches import Rectangle

# %% [markdown]
# Define data location

# %%
open_path = 'path'

# %%
open_path_2 = 'path'

# %% [markdown]
# Define saving path

# %%
save_path = 'D:/Gradu_koodit/Step_5_Plotting_results/Results/'

# %% [markdown]
# Open combined overpass and stacked diffs results

# %%
Combined_overpass_mean_mask1_201206 = xr.open_dataset(open_path_2+'combined_overpass_mean_062012_Mask1_sea.nc')

# %%
Combined_overpass_mean_mask1_201207 = xr.open_dataset(open_path_2+'combined_overpass_mean_072012_Mask1_sea.nc')

# %%
Combined_overpass_mean_mask1_201406 = xr.open_dataset(open_path_2+'combined_overpass_mean_062014_Mask1_sea.nc')

# %%
Combined_overpass_mean_mask1_201407 = xr.open_dataset(open_path_2+'combined_overpass_mean_072014_Mask1_sea.nc')

# %%
Combined_overpass_mean_mask2_201206 = xr.open_dataset(open_path_2+'combined_overpass_mean_062012_Mask2_sea_icesheet.nc')

# %%
Combined_overpass_mean_mask2_201207 = xr.open_dataset(open_path_2+'combined_overpass_mean_072012_Mask2_sea_icesheet.nc')

# %%
Combined_overpass_mean_mask2_201406 = xr.open_dataset(open_path_2+'combined_overpass_mean_062014_Mask2_sea_icesheet.nc')

# %%
Combined_overpass_mean_mask2_201407 = xr.open_dataset(open_path_2+'combined_overpass_mean_072014_Mask2_sea_icesheet.nc')

# %%
stacked_diffs_mask1_201206 = xr.open_dataset(open_path_2 + 'Stacked_diffs_062012_Mask1_sea.nc')

# %%
stacked_diffs_mask1_201207 = xr.open_dataset(open_path_2 + 'Stacked_diffs_072012_Mask1_sea.nc')

# %%
stacked_diffs_mask1_201406 = xr.open_dataset(open_path_2 + 'Stacked_diffs_062014_Mask1_sea.nc')

# %%
stacked_diffs_mask1_201407 = xr.open_dataset(open_path_2 + 'Stacked_diffs_072014_Mask1_sea.nc')

# %%
stacked_diffs_mask2_201206 = xr.open_dataset(open_path_2 + 'Stacked_diffs_062012_Mask2_sea_icesheet.nc')

# %%
stacked_diffs_mask2_201207 = xr.open_dataset(open_path_2 + 'Stacked_diffs_072012_Mask2_sea_icesheet.nc')

# %%
stacked_diffs_mask2_201406 = xr.open_dataset(open_path_2 + 'Stacked_diffs_062014_Mask2_sea_icesheet.nc')

# %%
stacked_diffs_mask2_201407 = xr.open_dataset(open_path_2 + 'Stacked_diffs_072014_Mask2_sea_icesheet.nc')

# %% [markdown]
# Plot observed results

# %%
sns.set(style="darkgrid")
fig, ax = plt.subplots(2,2, figsize=(15,15), subplot_kw={'projection':ccrs.LambertAzimuthalEqualArea(central_latitude=90)})

tgt  = pyresample.area_config.create_area_def('nhease2', 'epsg:6931', width=360, height=360, resolution=25000, area_extent= (-4487500.0, -4487500.0, 4487500.0, 4487500.0))
tgt_lon, tgt_lat = tgt.get_lonlats()


ax0 = ax[0,0]
ax0.coastlines(alpha=1)
ax0.gridlines(draw_labels=True, alpha=0.3)
image0 = ax0.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask1_201206['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax0.set_extent([-45,135,50,70])
ax0.set_title('06/2012')

ax1 = ax[0,1]
ax1.coastlines(alpha=1)
ax1.gridlines(draw_labels=True, alpha=0.3)
image1 = ax1.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask1_201207['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax1.set_extent([-45,135,50,70])
ax1.set_title('07/2012')

ax2 = ax[1,0]
ax2.coastlines(alpha=1)
ax2.gridlines(draw_labels=True, alpha=0.3)
image2 = ax2.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask1_201406['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax2.set_extent([-45,135,50,70])
ax2.set_title('06/2014')

ax3 = ax[1,1]
ax3.coastlines(alpha=1)
ax3.gridlines(draw_labels=True, alpha=0.3)
image3 = ax3.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask1_201407['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax3.set_extent([-45,135,50,70])
ax3.set_title('07/2014')

fig.suptitle('SAL and ToA difference Mask 1 ', fontsize=30)

cb_ax = fig.add_axes([0.93, 0.1, 0.02, 0.78])
cbar = fig.colorbar(image0, cax=cb_ax)

plt.savefig(save_path + 'SAL_ToA_difference_Map_mask1.png')
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(15,15), subplot_kw={'projection':ccrs.LambertAzimuthalEqualArea(central_latitude=90)})

tgt  = pyresample.area_config.create_area_def('nhease2', 'epsg:6931', width=360, height=360, resolution=25000, area_extent= (-4487500.0, -4487500.0, 4487500.0, 4487500.0))
tgt_lon, tgt_lat = tgt.get_lonlats()


ax0 = ax[0,0]
ax0.coastlines(alpha=1)
ax0.gridlines(draw_labels=True, alpha=0.3)
image0 = ax0.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask2_201206['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax0.set_extent([-45,135,50,70])
ax0.set_title('06/2012')

ax1 = ax[0,1]
ax1.coastlines(alpha=1)
ax1.gridlines(draw_labels=True, alpha=0.3)
image1 = ax1.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask2_201207['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax1.set_extent([-45,135,50,70])
ax1.set_title('07/2012')

ax2 = ax[1,0]
ax2.coastlines(alpha=1)
ax2.gridlines(draw_labels=True, alpha=0.3)
image2 = ax2.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask2_201406['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax2.set_extent([-45,135,50,70])
ax2.set_title('06/2014')

ax3 = ax[1,1]
ax3.coastlines(alpha=1)
ax3.gridlines(draw_labels=True, alpha=0.3)
image3 = ax3.pcolormesh(tgt_lon, tgt_lat, Combined_overpass_mean_mask2_201407['Diff_alb_SAL_TOA'], transform=ccrs.PlateCarree(), vmin=-0.2, vmax=0.2, cmap='RdBu_r')
ax3.set_extent([-45,135,50,70])
ax3.set_title('07/2014')

fig.suptitle('SAL and ToA difference Mask 2 ', fontsize=30)

cb_ax = fig.add_axes([0.93, 0.1, 0.02, 0.78])
cbar = fig.colorbar(image0, cax=cb_ax)

plt.savefig(save_path + 'SAL_ToA_difference_Map_mask2.png')
plt.show()

# %% [markdown]
# Calculate monthly averages for observed results

# %%
stacked_diffs_mask1_SAL_TOA_201206 = stacked_diffs_mask1_201206['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask1_SAL_TOA_201207 = stacked_diffs_mask1_201207['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask1_SAL_TOA_201406 = stacked_diffs_mask1_201406['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask1_SAL_TOA_201407 = stacked_diffs_mask1_201407['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask2_SAL_TOA_201206 = stacked_diffs_mask2_201206['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask2_SAL_TOA_201207 = stacked_diffs_mask2_201207['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask2_SAL_TOA_201406 = stacked_diffs_mask2_201406['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask2_SAL_TOA_201407 = stacked_diffs_mask2_201407['Diff_alb_SAL_TOA'].resample(time='1D').mean()

# %%
stacked_diffs_mask1_SAL_TOA_mean_201206 = stacked_diffs_mask1_SAL_TOA_201206.mean('time')

# %%
stacked_diffs_mask1_SAL_TOA_mean_201207 = stacked_diffs_mask1_SAL_TOA_201207.mean('time')

# %%
stacked_diffs_mask1_SAL_TOA_mean_201406 = stacked_diffs_mask1_SAL_TOA_201406.mean('time')

# %%
stacked_diffs_mask1_SAL_TOA_mean_201407 = stacked_diffs_mask1_SAL_TOA_201407.mean('time')

# %%
stacked_diffs_mask2_SAL_TOA_mean_201206 = stacked_diffs_mask2_SAL_TOA_201206.mean('time')

# %%
stacked_diffs_mask2_SAL_TOA_mean_201207 = stacked_diffs_mask2_SAL_TOA_201207.mean('time')

# %%
stacked_diffs_mask2_SAL_TOA_mean_201406 = stacked_diffs_mask2_SAL_TOA_201406.mean('time')

# %%
stacked_diffs_mask2_SAL_TOA_mean_201407 = stacked_diffs_mask2_SAL_TOA_201407.mean('time')

# %%
stacked_diffs_mask1_SAL_TOA_mean_list_201206 = []

# %%
stacked_diffs_mask1_SAL_TOA_mean_list_201207 = []

# %%
stacked_diffs_mask1_SAL_TOA_mean_list_201406 = []

# %%
stacked_diffs_mask1_SAL_TOA_mean_list_201407 = []

# %%
stacked_diffs_mask2_SAL_TOA_mean_list_201206 = []

# %%
stacked_diffs_mask2_SAL_TOA_mean_list_201207 = []

# %%
stacked_diffs_mask2_SAL_TOA_mean_list_201406 = []

# %%
stacked_diffs_mask2_SAL_TOA_mean_list_201407 = []

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask1_SAL_TOA_mean_201206.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask1_SAL_TOA_mean_list_201206.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:38<00:00,  9.21it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask1_SAL_TOA_mean_201207.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask1_SAL_TOA_mean_list_201207.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:39<00:00,  9.18it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask1_SAL_TOA_mean_201406.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask1_SAL_TOA_mean_list_201406.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:39<00:00,  9.12it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask1_SAL_TOA_mean_201407.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask1_SAL_TOA_mean_list_201407.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:39<00:00,  9.18it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask2_SAL_TOA_mean_201206.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask2_SAL_TOA_mean_list_201206.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:39<00:00,  9.15it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask2_SAL_TOA_mean_201207.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask2_SAL_TOA_mean_list_201207.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:38<00:00,  9.25it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask2_SAL_TOA_mean_201406.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask2_SAL_TOA_mean_list_201406.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:38<00:00,  9.23it/s]

# %%
for x in tqdm(range(1, 360)):
    for y in range(1, 360):
        Foo_point = stacked_diffs_mask2_SAL_TOA_mean_201407.sel(x=slice(x-1, x), y=slice(y-1, y))
        diff_point = float(Foo_point)
        stacked_diffs_mask2_SAL_TOA_mean_list_201407.append(diff_point)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 359/359 [00:39<00:00,  9.20it/s]

# %% [markdown]
# Plot SAL - ToA results

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")

f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201206, ax=ax1)
ax1.set_ylabel("Number of pixels")
ax1.set_xlabel("Difference in albedo Mask 1 06/2012")


sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201207, ax=ax2)
ax2.set_ylabel("Number of pixels")
ax2.set_xlabel("Difference in albedo Mask 1 07/2012")


sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201406, ax=ax3)
ax3.set_ylabel("Number of pixels")
ax3.set_xlabel("Difference in albedo Mask 1 06/2014")


sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201407, ax=ax4)
ax4.set_ylabel("Number of pixels")
ax4.set_xlabel("Difference in albedo Mask 1 07/2014")


plt.savefig(save_path +'SAL_TOA_difference_Mask_1.png')

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")

f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201206, ax=ax1)
ax1.set_ylabel("Number of pixels")
ax1.set_xlabel("Difference in albedo Mask 2 06/2012")


sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201207, ax=ax2)
ax2.set_ylabel("Number of pixels")
ax2.set_xlabel("Difference in albedo Mask 2 07/2012")


sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201406, ax=ax3)
ax3.set_ylabel("Number of pixels")
ax3.set_xlabel("Difference in albedo Mask 2 06/2014")


sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201407, ax=ax4)
ax4.set_ylabel("Number of pixels")
ax4.set_xlabel("Difference in albedo Mask 2 07/2014")


plt.savefig(save_path +'SAL_TOA_difference_Mask_2.png')

# %% [markdown]
# Open SMAC results

# %%
SMAC_diff_VIS_file_201206_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201206_r_diff_list_Mask1.txt')
SMAC_diff_VIS_201206_Mask1 = SMAC_diff_VIS_file_201206_Mask1.readlines()

# %%
SMAC_diff_NIR_file_201206_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201206_r_diff_list_Mask1.txt')
SMAC_diff_NIR_201206_Mask1 = SMAC_diff_NIR_file_201206_Mask1.readlines()

# %%
SMAC_diff_VIS_file_201207_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201207_r_diff_list_Mask1.txt')
SMAC_diff_VIS_201207_Mask1 = SMAC_diff_VIS_file_201207_Mask1.readlines()

# %%
SMAC_diff_NIR_file_201207_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201207_r_diff_list_Mask1.txt')
SMAC_diff_NIR_201207_Mask1 = SMAC_diff_NIR_file_201207_Mask1.readlines()

# %%
SMAC_diff_VIS_file_201406_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201406_r_diff_list_Mask1.txt')
SMAC_diff_VIS_201406_Mask1 = SMAC_diff_VIS_file_201406_Mask1.readlines()

# %%
SMAC_diff_NIR_file_201406_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201406_r_diff_list_Mask1.txt')
SMAC_diff_NIR_201406_Mask1 = SMAC_diff_NIR_file_201406_Mask1.readlines()

# %%
SMAC_diff_VIS_file_201407_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201407_r_diff_list_Mask1.txt')
SMAC_diff_VIS_201407_Mask1 = SMAC_diff_VIS_file_201407_Mask1.readlines()

# %%
SMAC_diff_NIR_file_201407_Mask1 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201407_r_diff_list_Mask1.txt')
SMAC_diff_NIR_201407_Mask1 = SMAC_diff_NIR_file_201407_Mask1.readlines()

# %%
SMAC_diff_VIS_file_201206_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201206_r_diff_list_Mask2.txt')
SMAC_diff_VIS_201206_Mask2 = SMAC_diff_VIS_file_201206_Mask2.readlines()

# %%
SMAC_diff_NIR_file_201206_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201206_r_diff_list_Mask2.txt')
SMAC_diff_NIR_201206_Mask2 = SMAC_diff_NIR_file_201206_Mask2.readlines()

# %%
SMAC_diff_VIS_file_201207_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201207_r_diff_list_Mask2.txt')
SMAC_diff_VIS_201207_Mask2 = SMAC_diff_VIS_file_201207_Mask2.readlines()

# %%
SMAC_diff_NIR_file_201207_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201207_r_diff_list_Mask2.txt')
SMAC_diff_NIR_201207_Mask2 = SMAC_diff_NIR_file_201207_Mask2.readlines()

# %%
SMAC_diff_VIS_file_201406_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201406_r_diff_list_Mask2.txt')
SMAC_diff_VIS_201406_Mask2 = SMAC_diff_VIS_file_201406_Mask2.readlines()

# %%
SMAC_diff_NIR_file_201406_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201406_r_diff_list_Mask2.txt')
SMAC_diff_NIR_201406_Mask2 = SMAC_diff_NIR_file_201406_Mask2.readlines()

# %%
SMAC_diff_VIS_file_201407_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/VIS201407_r_diff_list_Mask2.txt')
SMAC_diff_VIS_201407_Mask2 = SMAC_diff_VIS_file_201407_Mask2.readlines()

# %%
SMAC_diff_NIR_file_201407_Mask2 = open('O:/analyysi_backup/Step_4_SMAC/Masked_SMAC_results/NIR201407_r_diff_list_Mask2.txt')
SMAC_diff_NIR_201407_Mask2 = SMAC_diff_NIR_file_201407_Mask2.readlines()

# %% [markdown]
# Calculate broadband albedo

# %%
length201206_Mask1 = len(SMAC_diff_VIS_201206_Mask1)

# %%
length201207_Mask1 = len(SMAC_diff_VIS_201207_Mask1)

# %%
length201406_Mask1 = len(SMAC_diff_NIR_201406_Mask1)

# %%
length201407_Mask1 = len(SMAC_diff_VIS_201407_Mask1)

# %%
length201206_Mask2 = len(SMAC_diff_VIS_201206_Mask2)

# %%
length201207_Mask2 = len(SMAC_diff_VIS_201207_Mask2)

# %%
length201406_Mask2 = len(SMAC_diff_VIS_201406_Mask2)

# %%
length201407_Mask2 = len(SMAC_diff_VIS_201407_Mask2)

# %%
SMAC_diff_VIS_201206_Mask1_list = []
SMAC_diff_NIR_201206_Mask1_list = []
DIFF_SMAC_list_201206_Mask1 = []

# %%
SMAC_diff_VIS_201207_Mask1_list = []
SMAC_diff_NIR_201207_Mask1_list = []
DIFF_SMAC_list_201207_Mask1 = []

# %%
SMAC_diff_VIS_201406_Mask1_list = []
SMAC_diff_NIR_201406_Mask1_list = []
DIFF_SMAC_list_201406_Mask1 = []

# %%
SMAC_diff_VIS_201407_Mask1_list = []
SMAC_diff_NIR_201407_Mask1_list = []
DIFF_SMAC_list_201407_Mask1 = []

# %%
SMAC_diff_VIS_201206_Mask2_list = []
SMAC_diff_NIR_201206_Mask2_list = []
DIFF_SMAC_list_201206_Mask2 = []

# %%
SMAC_diff_VIS_201207_Mask2_list = []
SMAC_diff_NIR_201207_Mask2_list = []
DIFF_SMAC_list_201207_Mask2 = []

# %%
SMAC_diff_VIS_201406_Mask2_list = []
SMAC_diff_NIR_201406_Mask2_list = []
DIFF_SMAC_list_201406_Mask2 = []

# %%
SMAC_diff_VIS_201407_Mask2_list = []
SMAC_diff_NIR_201407_Mask2_list = []
DIFF_SMAC_list_201407_Mask2 = []

# %%
for i in range(length201206_Mask1):
    SMAC_diff_VIS_201206_Mask1_list.append(float(SMAC_diff_NIR_201206_Mask1[i][0:-1]))
    SMAC_diff_NIR_201206_Mask1_list.append(float(SMAC_diff_NIR_201206_Mask1[i][0:-1]))

# %%
for i in range(length201207_Mask1):
    SMAC_diff_VIS_201207_Mask1_list.append(float(SMAC_diff_NIR_201207_Mask1[i][0:-1]))
    SMAC_diff_NIR_201207_Mask1_list.append(float(SMAC_diff_NIR_201207_Mask1[i][0:-1]))

# %%
for i in range(length201406_Mask1):
    SMAC_diff_VIS_201406_Mask1_list.append(float(SMAC_diff_NIR_201406_Mask1[i][0:-1]))
    SMAC_diff_NIR_201406_Mask1_list.append(float(SMAC_diff_NIR_201406_Mask1[i][0:-1]))

# %%
for i in range(length201407_Mask1):
    SMAC_diff_VIS_201407_Mask1_list.append(float(SMAC_diff_NIR_201407_Mask1[i][0:-1]))
    SMAC_diff_NIR_201407_Mask1_list.append(float(SMAC_diff_NIR_201407_Mask1[i][0:-1]))

# %%
for i in range(length201206_Mask2):
    SMAC_diff_VIS_201206_Mask2_list.append(float(SMAC_diff_NIR_201206_Mask2[i][0:-1]))
    SMAC_diff_NIR_201206_Mask2_list.append(float(SMAC_diff_NIR_201206_Mask2[i][0:-1]))

# %%
for i in range(length201207_Mask2):
    SMAC_diff_VIS_201207_Mask2_list.append(float(SMAC_diff_NIR_201207_Mask2[i][0:-1]))
    SMAC_diff_NIR_201207_Mask2_list.append(float(SMAC_diff_NIR_201207_Mask2[i][0:-1]))

# %%
for i in range(length201406_Mask2):
    SMAC_diff_VIS_201406_Mask2_list.append(float(SMAC_diff_NIR_201406_Mask2[i][0:-1]))
    SMAC_diff_NIR_201406_Mask2_list.append(float(SMAC_diff_NIR_201406_Mask2[i][0:-1]))

# %%
for i in range(length201407_Mask2):
    SMAC_diff_VIS_201407_Mask2_list.append(float(SMAC_diff_NIR_201407_Mask2[i][0:-1]))
    SMAC_diff_NIR_201407_Mask2_list.append(float(SMAC_diff_NIR_201407_Mask2[i][0:-1]))

# %%
for i in range(length201206_Mask1):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201206_Mask1_list[i] + 0.464*SMAC_diff_NIR_201206_Mask1_list[i]
    DIFF_SMAC_list_201206_Mask1.append(DIFF_SMAC)

# %%
for i in range(length201207_Mask1):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201207_Mask1_list[i] + 0.464*SMAC_diff_NIR_201207_Mask1_list[i]
    DIFF_SMAC_list_201207_Mask1.append(DIFF_SMAC)

# %%
for i in range(length201406_Mask1):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201406_Mask1_list[i] + 0.464*SMAC_diff_NIR_201406_Mask1_list[i]
    DIFF_SMAC_list_201406_Mask1.append(DIFF_SMAC)

# %%
for i in range(length201407_Mask1):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201407_Mask1_list[i] + 0.464*SMAC_diff_NIR_201407_Mask1_list[i]
    DIFF_SMAC_list_201407_Mask1.append(DIFF_SMAC)

# %%
for i in range(length201206_Mask2):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201206_Mask2_list[i] + 0.464*SMAC_diff_NIR_201206_Mask2_list[i]
    DIFF_SMAC_list_201206_Mask2.append(DIFF_SMAC)

# %%
for i in range(length201207_Mask2):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201207_Mask2_list[i] + 0.464*SMAC_diff_NIR_201207_Mask2_list[i]
    DIFF_SMAC_list_201207_Mask2.append(DIFF_SMAC)

# %%
for i in range(length201406_Mask2):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201406_Mask2_list[i] + 0.464*SMAC_diff_NIR_201406_Mask2_list[i]
    DIFF_SMAC_list_201406_Mask2.append(DIFF_SMAC)

# %%
for i in range(length201407_Mask2):
    DIFF_SMAC = 0.007 + 0.434* SMAC_diff_VIS_201407_Mask2_list[i] + 0.464*SMAC_diff_NIR_201407_Mask2_list[i]
    DIFF_SMAC_list_201407_Mask2.append(DIFF_SMAC)

# %% [markdown]
# Plot graphs of observed and modelled broadband albedo results

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) , kde=True
sns.set(style="darkgrid")
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 11))

sns.histplot(data=DIFF_SMAC_list_201206_Mask1, color="blue", ax=ax1, kde=True)
sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201206, color="red", ax=ax1, kde=True)
ax1.set_xlabel("Surface Albedo - ToA albedo", fontsize=16)
ax1.set_ylabel("Frequency")
ax1.set_title("06/2012", fontsize=15)
ax1.set_xlim(-0.5, 0.3)
ax1.set_ylim(0, 3000)
#ax1.set_legend(title='Data', loc='upper right', labels=['SMAC diff', 'Observations diff'])
#plt.savefig('D:/analyysi/Plotting_ForLoop_results/Mask1_201206/Mask1_Observations_SMAC_diff_VIS.png')
ax1.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])


sns.histplot(data=DIFF_SMAC_list_201207_Mask1, color="blue", ax=ax2, kde=True)
sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201207, color="red", ax=ax2, kde=True)
ax2.set_xlabel("Surface Albedo - ToA albedo")
ax2.set_ylabel("Frequency")
ax2.set_title("07/2012", fontsize=15)
ax2.set_xlim(-0.5, 0.3)
ax2.set_ylim(0, 3000)
ax2.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])

sns.histplot(data=DIFF_SMAC_list_201406_Mask1, color="blue", ax=ax3, kde=True)
sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201406, color="red", ax=ax3, kde=True)
ax3.set_xlabel("Surface Albedo - ToA albedo")
ax3.set_ylabel("Frequency")
ax3.set_title("06/2014", fontsize=15)
ax3.set_xlim(-0.5, 0.3)
ax3.set_ylim(0, 3000)
ax3.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])


sns.histplot(data=DIFF_SMAC_list_201407_Mask1, color="blue", ax=ax4, kde=True)
sns.histplot(data=stacked_diffs_mask1_SAL_TOA_mean_list_201407, color="red", ax=ax4, kde=True)
ax4.set_xlabel("Surface Albedo - ToA albedo")
ax4.set_ylabel("Frequency")
ax4.set_title("07/2014", fontsize=15)
ax4.set_xlim(-0.5, 0.3)
ax4.set_ylim(0, 3000)
ax4.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])


#f.suptitle(' Observed and calculated SAL and TOA difference broadband albedo ', fontsize=30)
#plt.legend() 
#plt.savefig('D:/analyysi/Step_3_Plotting_ForLoop_results/Mask1_2_Combined_data_2012_2014/SAL_TOA_difference_broadband_mask1.png')


f.suptitle(' Mask 1: Observed and modelled SAL and ToA difference broadband albedo ', fontsize=30)
plt.show()

#plt.legend() 
#plt.savefig('D:/analyysi/Step_3_Plotting_ForLoop_results/Mask1_2_Combined_data_2012_2014/SAL_TOA_difference_broadband_mask2.png')
plt.savefig(save_path + 'SAL_TOA_difference_broadband_mask1.png')
#muuta x akseli samanskaalaiseksi
#tarkista datan lähde
#lisää legend

# %%
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) , kde=True
sns.set(style="darkgrid")
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 11))

sns.histplot(data=DIFF_SMAC_list_201206_Mask2, color="blue", ax=ax1, kde=True)
sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201206, color="red", ax=ax1, kde=True)
ax1.set_xlabel("Surface Albedo - ToA albedo")
ax1.set_ylabel("Frequency")
ax1.set_xlim(-0.5, 0.3)
ax1.set_ylim(0, 3000)
ax1.set_title("06/2012")
#ax1.set_legend(title='Data', loc='upper right', labels=['SMAC diff', 'Observations diff'])
#plt.savefig('D:/analyysi/Plotting_ForLoop_results/Mask1_201206/Mask1_Observations_SMAC_diff_VIS.png')
ax1.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])


sns.histplot(data=DIFF_SMAC_list_201207_Mask2, color="blue", ax=ax2, kde=True)
sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201207, color="red", ax=ax2, kde=True)
ax2.set_xlabel("Surface Albedo - ToA albedo")
ax2.set_ylabel("Frequency")
ax2.set_xlim(-0.5, 0.3)
ax2.set_ylim(0, 3000)
ax2.set_title("07/2012")
ax2.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])


sns.histplot(data=DIFF_SMAC_list_201406_Mask2, color="blue", ax=ax3, kde=True)
sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201406, color="red", ax=ax3, kde=True)
ax3.set_xlabel("Surface Albedo - ToA albedo")
ax3.set_ylabel("Frequency")
ax3.set_xlim(-0.5, 0.3)
ax3.set_ylim(0, 3000)
ax3.set_title("06/2014")
# position at which legend to be added
ax3.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])



sns.histplot(data=DIFF_SMAC_list_201407_Mask2, color="blue", ax=ax4, kde=True)
sns.histplot(data=stacked_diffs_mask2_SAL_TOA_mean_list_201407, color="red", ax=ax4, kde=True)
ax4.set_xlabel("Surface Albedo - ToA albedo")
ax4.set_ylabel("Frequency")
ax4.set_title("07/2014")
ax4.set_xlim(-0.5, 0.3)
ax4.set_ylim(0, 3000)
ax4.legend(title='Data', loc='upper left', labels=['SMAC diff', 'Observed diff'])

f.suptitle(' Mask 2: Observed and modelled SAL and ToA difference broadband albedo ', fontsize=30)


#plt.legend() 
#plt.savefig('D:/analyysi/Step_3_Plotting_ForLoop_results/Mask1_2_Combined_data_2012_2014/SAL_TOA_difference_broadband_mask2.png')
plt.savefig(save_path + 'SAL_TOA_difference_broadband_mask2.png')
plt.show()
